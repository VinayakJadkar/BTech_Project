# %%
# !pip install yfinance

# %%
import yfinance as yf
import pandas as pd
import numpy as np

# %%
stock_name ="HDFC.NS"

# %%
df = yf.Ticker(stock_name) 
print(df.history(period="5y"))
# Out:
#                    Open         High          Low        Close   Volume  \
# Date
# 2017-05-15  1453.274563  1470.195910  1452.900587  1457.948975  1270297
# 2017-05-16  1456.546749  1466.830455  1452.807220  1464.540039  2114918
# 2017-05-17  1463.558378  1468.653442  1448.833981  1451.404907  2161434
# 2017-05-18  1446.263094  1457.107707  1427.098004  1436.961060  2404372
# 2017-05-19  1444.393183  1447.197830  1416.673899  1421.582031  2142433
# ...                 ...          ...          ...          ...      ...
# 2022-05-09  2115.000000  2181.000000  2113.600098  2168.300049  3969231
# 2022-05-10  2163.449951  2221.800049  2160.250000  2201.300049  4205193
# 2022-05-11  2228.199951  2237.850098  2186.350098  2219.100098  3499620
# 2022-05-12  2190.000000  2204.000000  2143.000000  2150.449951  4361039
# 2022-05-13  2165.399902  2190.949951  2125.250000  2132.949951  4905109
#
#             Dividends  Stock Splits
# Date
# 2017-05-15        0.0             0
# ...

# %%
#df = yf.Ticker(stock_name+".NS") 
#print(df.history(period="5y"))

# %%
df1 = df.history(period="2y")
df1
len(df1)
# Out:
# 500

# %%
volu_df = df1[:-30]

volu_df
# Out:
#                    Open         High          Low        Close   Volume  \
# Date
# 2020-05-13  1693.399975  1695.823272  1645.903353  1660.200806  5734243
# 2020-05-14  1633.302311  1641.056863  1578.148044  1582.316162  5424645
# 2020-05-15  1598.406817  1606.888357  1559.634062  1583.673218  5609955
# 2020-05-18  1583.382293  1587.404989  1460.181894  1465.658569  8460057
# 2020-05-19  1521.830577  1542.913262  1465.610085  1492.605591  9261075
# ...                 ...          ...          ...          ...      ...
# 2022-03-23  2408.750000  2422.600098  2341.199951  2346.300049  3173223
# 2022-03-24  2318.000000  2356.949951  2303.550049  2310.500000  3994199
# 2022-03-25  2333.000000  2339.050049  2286.750000  2303.000000  3418282
# 2022-03-28  2310.000000  2313.899902  2234.100098  2268.250000  4734110
# 2022-03-29  2285.899902  2344.899902  2284.000000  2337.350098  3202852
#
#             Dividends  Stock Splits
# Date
# 2020-05-13        0.0             0
# ...

# %%
out_df = df1

# %%
total_date_df = df1
total_date_df
# Out:
#                    Open         High          Low        Close   Volume  \
# Date
# 2020-05-13  1693.399975  1695.823272  1645.903353  1660.200806  5734243
# 2020-05-14  1633.302311  1641.056863  1578.148044  1582.316162  5424645
# 2020-05-15  1598.406817  1606.888357  1559.634062  1583.673218  5609955
# 2020-05-18  1583.382293  1587.404989  1460.181894  1465.658569  8460057
# 2020-05-19  1521.830577  1542.913262  1465.610085  1492.605591  9261075
# ...                 ...          ...          ...          ...      ...
# 2022-05-09  2115.000000  2181.000000  2113.600098  2168.300049  3969231
# 2022-05-10  2163.449951  2221.800049  2160.250000  2201.300049  4205193
# 2022-05-11  2228.199951  2237.850098  2186.350098  2219.100098  3499620
# 2022-05-12  2190.000000  2204.000000  2143.000000  2150.449951  4361039
# 2022-05-13  2165.399902  2190.949951  2125.250000  2132.949951  4905109
#
#             Dividends  Stock Splits
# Date
# 2020-05-13        0.0             0
# ...

# %%
total_date_df = total_date_df.reset_index()

total_date_df['Date'] = pd.to_datetime(total_date_df.Date,format='%Y-%m-%d')

total_date_df = total_date_df['Date']
total_date_df
# Out:
# 0     2020-05-13
# 1     2020-05-14
# 2     2020-05-15
# 3     2020-05-18
# 4     2020-05-19
#          ...
# 495   2022-05-09
# 496   2022-05-10
# 497   2022-05-11
# 498   2022-05-12
# 499   2022-05-13
# Name: Date, Length: 500, dtype: datetime64[ns]

# %%
df1 = df1[0:-30]
df1
# Out:
#                    Open         High          Low        Close   Volume  \
# Date
# 2020-05-13  1693.399975  1695.823272  1645.903353  1660.200806  5734243
# 2020-05-14  1633.302311  1641.056863  1578.148044  1582.316162  5424645
# 2020-05-15  1598.406817  1606.888357  1559.634062  1583.673218  5609955
# 2020-05-18  1583.382293  1587.404989  1460.181894  1465.658569  8460057
# 2020-05-19  1521.830577  1542.913262  1465.610085  1492.605591  9261075
# ...                 ...          ...          ...          ...      ...
# 2022-03-23  2408.750000  2422.600098  2341.199951  2346.300049  3173223
# 2022-03-24  2318.000000  2356.949951  2303.550049  2310.500000  3994199
# 2022-03-25  2333.000000  2339.050049  2286.750000  2303.000000  3418282
# 2022-03-28  2310.000000  2313.899902  2234.100098  2268.250000  4734110
# 2022-03-29  2285.899902  2344.899902  2284.000000  2337.350098  3202852
#
#             Dividends  Stock Splits
# Date
# 2020-05-13        0.0             0
# ...

# %%
volume_df = df1

# %%
date_df1 = df1

date_df1 = date_df1.reset_index()

date_df1['Date'] = pd.to_datetime(date_df1.Date,format='%Y-%m-%d')
date_df1 = date_df1['Date']
date_df1
# Out:
# 0     2020-05-13
# 1     2020-05-14
# 2     2020-05-15
# 3     2020-05-18
# 4     2020-05-19
#          ...
# 465   2022-03-23
# 466   2022-03-24
# 467   2022-03-25
# 468   2022-03-28
# 469   2022-03-29
# Name: Date, Length: 470, dtype: datetime64[ns]

# %%
arr1 = [1,2,3,4,5,6,7,8]

# %%
arr1[-4:]
# Out:
# [5, 6, 7, 8]

# %%
mydf = date_df1[-30:]

mydf
# Out:
# 440   2022-02-14
# 441   2022-02-15
# 442   2022-02-16
# 443   2022-02-17
# 444   2022-02-18
# 445   2022-02-21
# 446   2022-02-22
# 447   2022-02-23
# 448   2022-02-24
# 449   2022-02-25
# 450   2022-02-28
# 451   2022-03-02
# 452   2022-03-03
# 453   2022-03-04
# 454   2022-03-07
# 455   2022-03-08
# 456   2022-03-09
# 457   2022-03-10
# 458   2022-03-11
# 459   2022-03-14
# 460   2022-03-15
# 461   2022-03-16
# 462   2022-03-17
# 463   2022-03-21
# 464   2022-03-22
# 465   2022-03-23
# 466   2022-03-24
# 467   2022-03-25
# 468   2022-03-28
# 469   2022-03-29
# Name: Date, dtype: datetime64[ns]

# %%
df1=df1.reset_index()['Close']
df1
# Out:
# 0      1660.200806
# 1      1582.316162
# 2      1583.673218
# 3      1465.658569
# 4      1492.605591
#           ...
# 465    2346.300049
# 466    2310.500000
# 467    2303.000000
# 468    2268.250000
# 469    2337.350098
# Name: Close, Length: 470, dtype: float64

# %%
#df1['Date'] = pd.to_datetime(df1.Date,format='%Y-%m-%d')
#df1.index = df1['Date']
#df1 = df1[['Date','Close']]

# %%
len(df1)
# Out:
# 470

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(16,8))
plt.plot(date_df1,df1)
plt.savefig('my_plot.png')

# %%
from PIL import Image

im = Image.open("my_plot.png")

# %%
im.show()

# %%
import numpy as np

# %%
df2 = df1

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
print (df1)
# Out:
# [[0.13214666]
#  [0.08172896]
#  [0.08260744]
#  [0.00621206]
#  [0.02365589]
#  [0.07834055]
#  [0.05970453]
#  [0.00878466]
#  [0.        ]
#  [0.04282538]
#  [0.07626981]
#  [0.09835706]
#  [0.14780217]
#  [0.19539638]
#  [0.20926365]
#  [0.16449317]
#  [0.16593625]
#  [0.16229695]
#  [0.1693874 ]
#  [0.19272966]
#  [0.17901917]
#  [0.18199975]
#  [0.15655554]
#  [0.20063577]
#  [0.1835371 ]
#  [0.2220014 ]
#  [0.20891849]
#  [0.19906713]
#  [0.21080092]
#  [0.18548219]
#  [0.17296412]
#  [0.16766191]
#  [0.14996702]
#  [0.15843797]
#  [0.20894986]
#  [0.2430218 ]
#  [0.240355  ]
#  [0.2300017 ]
#  [0.24132767]
#  [0.24088847]
#  [0.28962129]
#  [0.26726576]
#  [0.24131795]
#  [0.2067101 ]
#  [0.20561961]
#  [0.20427246]
#  [0.21585114]
#  [0.21597947]
#  [0.26575828]
#  [0.26409047]
#  [0.26072268]
#  [0.23859165]
#  [0.24465357]
#  [0.2745465 ]
#  [0.26168492]
#  [0.21893026]
#  [0.20051977]
#  [0.17348147]
#  [0.19997452]
#  [0.19715198]
#  [0.2016745 ]
#  [0.19779347]
# ...

# %%
##splitting dataset into train and test split
training_size=int(len(df1)*0.65)
test_size=len(df1)-training_size
train_data,test_data=df1[0:training_size,:],df1[training_size:len(df1),:1]

# %%
training_size,test_size
# Out:
# (305, 165)

# %%
new_df = df2[100:training_size-1]
new_df
# Out:
# 100    1774.444092
# 101    1768.944214
# 102    1916.893066
# 103    1931.113159
# 104    1931.608643
#           ...
# 299    2490.300049
# 300    2482.500000
# 301    2464.300049
# 302    2433.949951
# 303    2425.800049
# Name: Close, Length: 204, dtype: float64

# %%
test_len = test_size - 101
test_len
# Out:
# 64

# %%
nd_df = df2[-test_len:]
nd_df
# Out:
# 406    2558.850098
# 407    2565.350098
# 408    2563.550049
# 409    2563.699951
# 410    2586.449951
#           ...
# 465    2346.300049
# 466    2310.500000
# 467    2303.000000
# 468    2268.250000
# 469    2337.350098
# Name: Close, Length: 64, dtype: float64

# %%
neww_df = np.array(nd_df).reshape(-1,1)
neww_df
# Out:
# array([[2558.85009766],
#        [2565.35009766],
#        [2563.55004883],
#        [2563.69995117],
#        [2586.44995117],
#        [2636.39990234],
#        [2675.30004883],
#        [2673.64990234],
#        [2620.39990234],
#        [2596.69995117],
#        [2659.64990234],
#        [2710.94995117],
#        [2737.5       ],
#        [2756.        ],
#        [2712.44995117],
#        [2702.69995117],
#        [2662.5       ],
#        [2620.25      ],
#        [2569.30004883],
#        [2592.94995117],
#        [2539.80004883],
#        [2530.60009766],
#        [2503.35009766],
#        [2516.5       ],
#        [2521.        ],
#        [2565.35009766],
#        [2612.94995117],
#        [2527.80004883],
#        [2503.25      ],
#        [2428.14990234],
#        [2414.60009766],
#        [2435.35009766],
#        [2476.55004883],
#        [2426.35009766],
#        [2296.80004883],
#        [2340.25      ],
#        [2363.85009766],
#        [2411.80004883],
# ...

# %%
ndf = np.array(new_df).reshape(-1,1)
ndf
# Out:
# array([[1774.4440918 ],
#        [1768.94421387],
#        [1916.89306641],
#        [1931.11315918],
#        [1931.60864258],
#        [1939.93273926],
#        [1947.61254883],
#        [1925.81164551],
#        [1961.9317627 ],
#        [1929.57714844],
#        [1943.94592285],
#        [2013.11425781],
#        [1997.06091309],
#        [2030.20812988],
#        [2024.06433105],
#        [2041.05908203],
#        [2054.58569336],
#        [2022.87512207],
#        [1951.08081055],
#        [1916.79406738],
#        [1906.14135742],
#        [2022.3302002 ],
#        [2111.66430664],
#        [2069.30102539],
#        [2081.68798828],
#        [2119.09643555],
#        [2132.62304688],
#        [2251.53686523],
#        [2303.2644043 ],
#        [2310.99389648],
#        [2285.87329102],
#        [2290.33251953],
#        [2327.74072266],
#        [2343.49682617],
#        [2303.56176758],
#        [2313.66943359],
#        [2230.4296875 ],
#        [2197.62915039],
# ...

# %%
train_data
# Out:
# array([[0.13214666],
#        [0.08172896],
#        [0.08260744],
#        [0.00621206],
#        [0.02365589],
#        [0.07834055],
#        [0.05970453],
#        [0.00878466],
#        [0.        ],
#        [0.04282538],
#        [0.07626981],
#        [0.09835706],
#        [0.14780217],
#        [0.19539638],
#        [0.20926365],
#        [0.16449317],
#        [0.16593625],
#        [0.16229695],
#        [0.1693874 ],
#        [0.19272966],
#        [0.17901917],
#        [0.18199975],
#        [0.15655554],
#        [0.20063577],
#        [0.1835371 ],
#        [0.2220014 ],
#        [0.20891849],
#        [0.19906713],
#        [0.21080092],
#        [0.18548219],
#        [0.17296412],
#        [0.16766191],
#        [0.14996702],
#        [0.15843797],
#        [0.20894986],
#        [0.2430218 ],
#        [0.240355  ],
#        [0.2300017 ],
#        [0.24132767],
#        [0.24088847],
#        [0.28962129],
#        [0.26726576],
#        [0.24131795],
# ...

# %%
test_data
# Out:
# array([[0.63768475],
#        [0.65121421],
#        [0.71115762],
#        [0.78974456],
#        [0.78045519],
#        [0.75870473],
#        [0.75598578],
#        [0.78689618],
#        [0.77838374],
#        [0.78501896],
#        [0.80793466],
#        [0.82541279],
#        [0.83010599],
#        [0.81220716],
#        [0.81952211],
#        [0.81945731],
#        [0.79958407],
#        [0.80476277],
#        [0.80547491],
#        [0.8170298 ],
#        [0.84130497],
#        [0.86901108],
#        [0.83615867],
#        [0.85554641],
#        [0.84318235],
#        [0.84751948],
#        [0.89393359],
#        [0.88894912],
#        [0.88946702],
#        [0.90221955],
#        [0.88166657],
#        [0.87998342],
#        [0.87797677],
#        [0.88658624],
#        [0.83276014],
#        [0.85337792],
#        [0.82771087],
#        [0.8812457 ],
#        [0.89522827],
#        [0.89574617],
#        [0.87318637],
#        [0.8353171 ],
#        [0.84039876],
# ...

# %%
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100 
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return numpy.array(dataX), numpy.array(dataY)

# %%
new_train_data = train_data[100:-1]
new_train_data
# Out:
# array([[0.20610069],
#        [0.20254041],
#        [0.29831333],
#        [0.30751854],
#        [0.30783929],
#        [0.31322779],
#        [0.31819922],
#        [0.30408667],
#        [0.3274686 ],
#        [0.30652422],
#        [0.31582568],
#        [0.36060098],
#        [0.35020903],
#        [0.37166649],
#        [0.36768937],
#        [0.37869072],
#        [0.38744701],
#        [0.36691955],
#        [0.32044436],
#        [0.29824925],
#        [0.29135334],
#        [0.36656681],
#        [0.42439617],
#        [0.39697281],
#        [0.40499136],
#        [0.42920727],
#        [0.43796357],
#        [0.51494101],
#        [0.54842621],
#        [0.55342981],
#        [0.53716828],
#        [0.54005491],
#        [0.56427067],
#        [0.57447019],
#        [0.54861871],
#        [0.55516179],
#        [0.50127753],
#        [0.48004449],
#        [0.46314163],
#        [0.49332298],
#        [0.50477357],
#        [0.53729646],
#        [0.51766738],
# ...

# %%
new_train_data.shape
# Out:
# (204, 1)

# %%
# reshape into X=t,t+1,t+2,t+3 and Y=t+4
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
print(X_train.shape), print(y_train.shape)
# Out:
# (204, 100)
# (204,)
# (None, None)

# %%
print(X_test.shape), print(ytest.shape)
# Out:
# (64, 100)
# (64,)
# (None, None)

# %%
# reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
### Create the Stacked LSTM model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_3 (LSTM)               (None, 100, 50)           10400
#
#  lstm_4 (LSTM)               (None, 100, 50)           20200
#
#  lstm_5 (LSTM)               (None, 50)                20200
#
#  dense_1 (Dense)             (None, 1)                 51
#
# ...
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_3 (LSTM)               (None, 100, 50)           10400
#
#  lstm_4 (LSTM)               (None, 100, 50)           20200
#
#  lstm_5 (LSTM)               (None, 50)                20200
#
#  dense_1 (Dense)             (None, 1)                 51
#
# ...
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=50,batch_size=64,verbose=1)
# Out:
# Epoch 1/50
# 4/4 [==============================] - 9s 744ms/step - loss: 0.2711 - val_loss: 0.0271
# Epoch 2/50
# 4/4 [==============================] - 2s 366ms/step - loss: 0.0319 - val_loss: 0.0988
# Epoch 3/50
# 4/4 [==============================] - 2s 437ms/step - loss: 0.0259 - val_loss: 0.0056
# Epoch 4/50
# 4/4 [==============================] - 2s 369ms/step - loss: 0.0151 - val_loss: 0.0145
# Epoch 5/50
# 4/4 [==============================] - 2s 468ms/step - loss: 0.0162 - val_loss: 0.0055
# Epoch 6/50
# 4/4 [==============================] - 2s 424ms/step - loss: 0.0044 - val_loss: 0.0223
# Epoch 7/50
# 4/4 [==============================] - 2s 412ms/step - loss: 0.0098 - val_loss: 0.0150
# Epoch 8/50
# 4/4 [==============================] - 2s 424ms/step - loss: 0.0049 - val_loss: 0.0056
# Epoch 9/50
# 4/4 [==============================] - 2s 438ms/step - loss: 0.0048 - val_loss: 0.0054
# Epoch 10/50
# ...

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.8.0'

# %%
### Lets Do the prediction and check performance metrics
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)

# %%
##Transformback to original form
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
### Calculate RMSE performance metrics
import math
from sklearn.metrics import mean_squared_error
math.sqrt(np.mean(ndf-train_predict)**2)
# Out:
# 0.37555769378063725

# %%
### Test Data RMSE
math.sqrt(np.mean(neww_df-test_predict)**2)
# Out:
# 73.63319778442383

# %%
ndf,train_predict
# Out:
# (array([[1774.4440918 ],
#         [1768.94421387],
#         [1916.89306641],
#         [1931.11315918],
#         [1931.60864258],
#         [1939.93273926],
#         [1947.61254883],
#         [1925.81164551],
#         [1961.9317627 ],
#         [1929.57714844],
#         [1943.94592285],
#         [2013.11425781],
#         [1997.06091309],
#         [2030.20812988],
#         [2024.06433105],
#         [2041.05908203],
#         [2054.58569336],
#         [2022.87512207],
#         [1951.08081055],
#         [1916.79406738],
#         [1906.14135742],
#         [2022.3302002 ],
#         [2111.66430664],
#         [2069.30102539],
#         [2081.68798828],
#         [2119.09643555],
#         [2132.62304688],
#         [2251.53686523],
#         [2303.2644043 ],
#         [2310.99389648],
#         [2285.87329102],
#         [2290.33251953],
#         [2327.74072266],
#         [2343.49682617],
#         [2303.56176758],
#         [2313.66943359],
#         [2230.4296875 ],
# ...

# %%
ytest,test_predict
# Out:
# (array([0.69814622, 0.71387657, 0.71808426, 0.71691902, 0.71701606,
#         0.731743  , 0.76407751, 0.78925906, 0.78819085, 0.7537201 ,
#         0.73837822, 0.77912812, 0.81233659, 0.82952345, 0.84149921,
#         0.8133076 , 0.80699606, 0.7809731 , 0.75362306, 0.72064122,
#         0.7359507 , 0.70154475, 0.69558927, 0.6779493 , 0.68646174,
#         0.68937476, 0.71808426, 0.74889746, 0.69377669, 0.67788451,
#         0.62926935, 0.62049805, 0.63393031, 0.66060061, 0.62810427,
#         0.54424159, 0.5723684 , 0.58764564, 0.61868547, 0.63768475,
#         0.63486892, 0.64597071, 0.63503076, 0.57418098, 0.61192082,
#         0.58806635, 0.5321364 , 0.52883491, 0.49290765, 0.43105446,
#         0.45031277, 0.47795408, 0.50614568, 0.50099938, 0.53058269,
#         0.50802306, 0.54119913, 0.62091876, 0.60580335, 0.61282703,
#         0.57628483, 0.55311009, 0.54825506, 0.52576006]), array([[2667.2737],
#         [2657.3706],
#         [2647.2148],
#         [2637.1675],
# ...

# %%
### Plotting 
# shift train predictions for plotting
plt.figure(figsize=(16,8))
look_back=100
trainPredictPlot = numpy.empty_like(df1)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(df1)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df1)-1, :] = test_predict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(df1))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
test_length = len(test_data)
test_length
# Out:
# 165

# %%
new_test_length = test_length - 100
new_test_length
# Out:
# 65

# %%
x_input=test_data[new_test_length:].reshape(1,-1)
x_input.shape
# Out:
# (1, 100)

# %%
temp_input=list(x_input)
temp_input=temp_input[0].tolist()

# %%
temp_input
# Out:
# [0.9320617417661552,
#  0.9345216580894897,
#  0.9862116672258703,
#  0.9616452185880222,
#  0.9642345709196325,
#  0.9404448963729628,
#  0.9946917012869796,
#  1.0,
#  0.9835575178693601,
#  0.9660469911185405,
#  0.9511582152117812,
#  0.9313821632123267,
#  0.9389235886615321,
#  0.9240672112672228,
#  0.9138392379490572,
#  0.8322422409908825,
#  0.8141815716945102,
#  0.78783494332868,
#  0.8076109953281345,
#  0.8750313514873524,
#  0.8516299849655098,
#  0.849785166254152,
#  0.8813104992832026,
#  0.9042910012262442,
#  0.8972026808267657,
#  0.8756462910578051,
#  0.8517595790153096,
#  0.8388774563406338,
#  0.8193602763577308,
#  0.8049894025255984,
#  0.7517458452068613,
#  0.7083417951399387,
#  0.702224481864814,
#  0.7010268431948348,
#  0.7218386993435428,
#  0.698146220334223,
#  0.7138765673570606,
#  0.7180842648959274,
#  0.7169190247383979,
#  0.7170160622342234,
#  0.7317430036202572,
#  0.7640775092529362,
#  0.789259055502761,
#  0.788190852841057,
# ...

# %%
# demonstrate prediction for next 10 days
from numpy import array

lst_output=[]
n_steps=100
i=0
while(i<30):
    
    if(len(temp_input)>100):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i=i+1
    

print(lst_output)
# Out:
# [0.5953944]
# 101
# 1 day input [0.93452166 0.98621167 0.96164522 0.96423457 0.9404449  0.9946917
#  1.         0.98355752 0.96604699 0.95115822 0.93138216 0.93892359
#  0.92406721 0.91383924 0.83224224 0.81418157 0.78783494 0.807611
#  0.87503135 0.85162998 0.84978517 0.8813105  0.904291   0.89720268
#  0.87564629 0.85175958 0.83887746 0.81936028 0.8049894  0.75174585
#  0.7083418  0.70222448 0.70102684 0.7218387  0.69814622 0.71387657
#  0.71808426 0.71691902 0.71701606 0.731743   0.76407751 0.78925906
#  0.78819085 0.7537201  0.73837822 0.77912812 0.81233659 0.82952345
#  0.84149921 0.8133076  0.80699606 0.7809731  0.75362306 0.72064122
#  0.7359507  0.70154475 0.69558927 0.6779493  0.68646174 0.68937476
#  0.71808426 0.74889746 0.69377669 0.67788451 0.62926935 0.62049805
#  0.63393031 0.66060061 0.62810427 0.54424159 0.5723684  0.58764564
#  0.61868547 0.63768475 0.63486892 0.64597071 0.63503076 0.57418098
#  0.61192082 0.58806635 0.5321364  0.52883491 0.49290765 0.43105446
# ...

# %%
day_new=np.arange(1,101)
day_pred=np.arange(101,131)

# %%
length = len(df1)
length
# Out:
# 470

# %%
new_length = length - 100
new_length
# Out:
# 370

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(16,8))
plt.plot(day_new,scaler.inverse_transform(df1[new_length:]))
plt.plot(day_pred,scaler.inverse_transform(lst_output))

# %%
plt.figure(figsize=(16,8))
df3=df1.tolist()
df3.extend(lst_output)
plt.plot(df3[400:])

# %%
df3=scaler.inverse_transform(df3).tolist()

# %%
plt.figure(figsize=(16,8))
plt.plot(total_date_df,df3)
plt.plot(out_df['Close'])
plt.savefig('final_plot.png')

# %%
volume_mean = volume_df['Volume'].mean()
volume_mean
# Out:
# 4165749.876595745

# %%
##volume_df['Volume'].tail(30)

##volume_df.index.tail(30)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-121-0f6b84c0e485> in <module>()
#       1 volume_df['Volume'].tail(30)
#       2
# ----> 3 volume_df.index.tail(30)
#
# AttributeError: 'DatetimeIndex' object has no attribute 'tail'

# %%
plt.figure(figsize=(16,8))
plt.plot(mydf,volume_df['Volume'].tail(30))
# corresponding y axis values

# plotting the points
# plt.plot(mydf,volume_df['Volume'].tail(30))
plt.axhline(y = volume_mean, color = 'r', linestyle = '-')

plt.show()

# %% [markdown]
# # Performance Metrics

# %% [markdown]
# ## MAPE

# %%
from sklearn.metrics import accuracy_score

# %%
y = neww_df
y_hat = test_predict

# %%
x = ndf
x_hat = train_predict

# %%
mape_train = np.mean(np.abs((x - x_hat)/x))*100
mape_train
# Out:
# 2.9071426126083586

# %%
mape_test = np.mean(np.abs((y- y_hat)/y))*100
mape_test
# Out:
# 4.517853886158083

# %% [markdown]
# ## R-squared

# %%
from sklearn.metrics import r2_score

# %%
r2_x = r2_score(x,x_hat)
r2_x
# Out:
# 0.8286614392204762

# %%
r2_y =r2_score(y,y_hat)
r2_y
# Out:
# 0.3182522865399936

# %% [markdown]
# ## MBE

# %%
def MBE(y_true, y_pred):
    '''
    Parameters:
        y_true (array): Array of observed values
        y_pred (array): Array of prediction values

    Returns:
        mbe (float): Biais score
    '''
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    y_true = y_true.reshape(len(y_true),1)
    y_pred = y_pred.reshape(len(y_pred),1)   
    diff = (y_true-y_pred)
    mbe = diff.mean()
    print('MBE = ', mbe)

# %%
MBE(y,y_hat)
# Out:
# MBE =  -73.63319778442383

# %%
pip install python-docx
# Out:
# ...
#      |████████████████████████████████| 5.6 MB 5.3 MB/s
# ...
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184507 sha256=bbf576038a85ddbcce058aa8428609961b48eac7d077e635152036eef6aa2043
#   Stored in directory: /root/.cache/pip/wheels/f6/6f/b9/d798122a8b55b74ad30b5f52b01482169b445fbb84a11797a6
# Successfully built python-docx
# ...

# %%
df.info
# Out:
# {'52WeekChange': -0.14217055,
#  'SandP52WeekChange': -0.033483148,
#  'address1': 'HDFC House',
#  'address2': 'H T Parekh Marg 165-166, Backbay Reclamation Churchgate',
#  'algorithm': None,
#  'annualHoldingsTurnover': None,
#  'annualReportExpenseRatio': None,
#  'ask': 0,
#  'askSize': 0,
#  'averageDailyVolume10Day': 4010891,
#  'averageVolume': 5575407,
#  'averageVolume10days': 4010891,
#  'beta': 0.920994,
#  'beta3Year': None,
#  'bid': 0,
#  'bidSize': 0,
#  'bookValue': 905.589,
#  'category': None,
#  'circulatingSupply': None,
#  'city': 'Mumbai',
#  'companyOfficers': [],
#  'country': 'India',
#  'currency': 'INR',
#  'currentPrice': 2132.95,
#  'currentRatio': None,
#  'dateShortInterest': None,
#  'dayHigh': 2190.95,
#  'dayLow': 2125.25,
#  'debtToEquity': None,
#  'dividendRate': 30,
#  'dividendYield': 0.014099999,
#  'earningsGrowth': 0.106,
#  'earningsQuarterlyGrowth': 0.128,
#  'ebitda': None,
#  'ebitdaMargins': 0,
#  'enterpriseToEbitda': None,
# ...

# %%
Volume = df.info['volume'],
Ten_days_volume_avg = ['averageVolume10days']
Current_price = ['currentPrice']

# %%
import docx
  
# Create an instance of a word document
doc = docx.Document()
    
# Image in its native size
doc.add_heading('Image in Native Size:', 0)
doc.add_picture('final_plot.png')

doc.add_heading(Current_price,3)

#doc.add_heading(Volume ,3)

doc.add_heading(Ten_days_volume_avg,3)

# Now save the document to a location
doc.save('gfg.docx')
